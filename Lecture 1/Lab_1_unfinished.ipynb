# %% [markdown]
# ## Lab 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Manual Dicctionary Construction
date = {
  'Country':[],
  'iso_a30':[],
  '':[],

}
